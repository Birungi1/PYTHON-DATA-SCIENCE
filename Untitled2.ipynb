# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
e=[100,200,300,400,500,600,700]
f=[1000,1500,3000,5000,7000,9000,10000]
s=[300,200,500,400,900,1000,1100]
plt.plot(e,f)
plt.plot(e,s)
plt.title("the graph of e angainst f")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.legend(["X-label","Ylabel"])

# %%
plt.plot(e,f)
