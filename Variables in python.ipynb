# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
x=[1,2,3,4]
y=[1,4,9,10]
z=[3,4,5,6]
plt.plot(x,y)
plt.plot(x,z)
plt.title("test plot")
plt.xlabel("x")
plt.ylabel("y and z")
plt.legend(["this is Y","this is z"])
plt.show()
